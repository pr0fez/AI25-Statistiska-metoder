# %%
import pandas as pd

data_path = "/home/raphael/Documents/iths/data/"

df = pd.read_csv(data_path+"Hitters.csv")

df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
df.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   380.928571  101.024845   10.770186   50.909938   48.027950   38.742236
# std    153.404981   46.454741    8.709037   26.024095   26.166895   21.639327
# min     16.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    255.250000   64.000000    4.000000   30.250000   28.000000   22.000000
# 50%    379.500000   96.000000    8.000000   48.000000   44.000000   35.000000
# 75%    512.000000  137.000000   16.000000   69.000000   64.750000   53.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years       CAtBat        CHits      CHmRun        CRuns  \
# count  322.000000    322.00000   322.000000  322.000000   322.000000
# mean     7.444099   2648.68323   717.571429   69.490683   358.795031
# std      4.926087   2324.20587   654.472627   86.266061   334.105886
# min      1.000000     19.00000     4.000000    0.000000     1.000000
# 25%      4.000000    816.75000   209.000000   14.000000   100.250000
# 50%      6.000000   1928.00000   508.000000   37.500000   247.000000
# 75%     11.000000   3924.25000  1059.250000   90.000000   526.250000
# max     24.000000  14053.00000  4256.000000  548.000000  2165.000000
#
#               CRBI       CWalks      PutOuts     Assists      Errors  \
# count   322.000000   322.000000   322.000000  322.000000  322.000000
# mean    330.118012   260.239130   288.937888  106.913043    8.040373
# std     333.219617   267.058085   280.704614  136.854876    6.368359
# min       0.000000     0.000000     0.000000    0.000000    0.000000
# 25%      88.750000    67.250000   109.250000    7.000000    3.000000
# 50%     220.500000   170.500000   212.000000   39.500000    6.000000
# 75%     426.250000   339.250000   325.000000  166.000000   11.000000
# max    1659.000000  1566.000000  1378.000000  492.000000   32.000000
#
#             Salary
# count   263.000000
# mean    535.925882
# std     451.118681
# min      67.500000
# 25%     190.000000
# 50%     425.000000
# 75%     750.000000
# max    2460.000000

# %%
df['Salary'].hist()
# Out:
# <Axes: >

# %%
df['Salary'].hist(cumulative=True)
# Out:
# <Axes: >

# %%
df[['AtBat','Hits','HmRun','Runs']].corr()
# Out:
#           AtBat      Hits     HmRun      Runs
# AtBat  1.000000  0.967939  0.592198  0.913060
# Hits   0.967939  1.000000  0.562158  0.922187
# HmRun  0.592198  0.562158  1.000000  0.650988
# Runs   0.913060  0.922187  0.650988  1.000000

# %%
import scipy . stats as stats
import matplotlib.pyplot as plt
ax = plt.axes()
stats.probplot(df["Salary"].to_numpy(), plot=ax)
plt.show()

# %%
df[['AtBat', 'Salary']].boxplot()
# Out:
# <Axes: >

# %%
df = pd.read_csv(data_path+'Auto.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.drop(['displacement', 'weight'], axis=1).boxplot()
# Out:
# <Axes: >

# %%
import numpy as np

Y = df['mpg']
X = df[['weight', 'year']]
X = np.column_stack([np.ones(Y.shape[0]), X])
X
# Out:
# array([[1.000e+00, 3.504e+03, 7.000e+01],
#        [1.000e+00, 3.693e+03, 7.000e+01],
#        [1.000e+00, 3.436e+03, 7.000e+01],
#        ...,
#        [1.000e+00, 2.295e+03, 8.200e+01],
#        [1.000e+00, 2.625e+03, 8.200e+01],
#        [1.000e+00, 2.720e+03, 8.200e+01]], shape=(397, 3))

# %%
b = np.linalg.pinv(X.T@X) @ X.T @ Y

# %%
import scipy.stats as stats

k = len(b)-1
n = Y.shape[0]
SSE = np.sum(np.square(Y - (X @ b)))
var = SSE/(n-k-1)
S = np.sqrt(var)

Syy = (n*np.sum(np.square(Y)) - np.square(np.sum(Y)))/n
SSR = Syy - SSE

sig_statistic = (SSR/k)/S
# Tests all parameters at once!
p_val = stats.f.sf(sig_statistic, k, n-k-1)
p_val
# Out:
# np.float64(2.8504506581429946e-235)

# %%
plt.scatter(X@b, Y)

# %%
Rsq = SSR/Syy
Rsq
# Out:
# np.float64(0.8087475430653486)

# %%
c = np.linalg.pinv(X.T @ X)*var

i = 2
b_statistic = b[i] / (S*np.sqrt(c[i, i]))
p_b = 2*min(stats.t.cdf(b_statistic, n-k-1), stats.t.sf(b_statistic, n-k-1))
p_b
# Out:
# np.float64(8.041565740911161e-06)
